# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Sample_data = {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}

# %%
df = pd.DataFrame(Sample_data)
df
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

new_df = pd.DataFrame(exam_data, index=labels)
new_df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     8 non-null      float64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
new_df.head(3)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
df = pd.DataFrame(exam_data , index=labels)

print(df[['name','score']])
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
plt.scatter('score', 'attempts')

# %%
new_df.isna
# Out:
# <bound method DataFrame.isna of         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes>

# %%
new_df.dropna()
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
new_df.dropna(inplace=True)

# %%
new_df[['score', 'qualify']]
# Out:
#    score qualify
# a   12.5     yes
# b    9.0      no
# c   16.5     yes
# e    9.0      no
# f   20.0     yes
# g   14.5     yes
# i    8.0      no
# j   19.0     yes

# %%
new_data = pd.read_csv('/content/drive/MyDrive/Machine Learning and Data Science/9.1 lsd_math_score_data.csv.csv')

# %%
new_data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
time = new_data['Time_Delay_in_Minutes']
lsd = new_data['LSD_ppm']
plt.plot(time, lsd)

# %%
print("Daily studying Time: \n")
only_math_score = new_data['Avg_Math_Test_Score']
only_math_score
# Out:
# Daily studying Time:
# 0    78.93
# 1    58.20
# 2    67.47
# 3    37.47
# 4    45.65
# 5    32.92
# 6    29.97
# Name: Avg_Math_Test_Score, dtype: float64

# %%
new_data['New_column'] = new_data['Avg_Math_Test_Score']
added_column = new_data['New_column']
added_column
# Out:
# 0    78.93
# 1    58.20
# 2    67.47
# 3    37.47
# 4    45.65
# 5    32.92
# 6    29.97
# Name: New_column, dtype: float64

# %%
new_data['High_score'] = 100

# %%
new_data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score  New_column  High_score
# 0                      5     1.17                78.93       78.93         100
# 1                     15     2.97                58.20       58.20         100
# 2                     30     3.26                67.47       67.47         100
# 3                     60     4.69                37.47       37.47         100
# 4                    120     5.83                45.65       45.65         100
# 5                    240     6.00                32.92       32.92         100
# 6                    480     6.41                29.97       29.97         100

# %%
new_data['High_score'] = new_data['High_score'] + new_data['Avg_Math_Test_Score']

# %%
new_data
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score  New_column  High_score
# 0                      5     1.17                78.93       78.93      178.93
# 1                     15     2.97                58.20       58.20      158.20
# 2                     30     3.26                67.47       67.47      167.47
# 3                     60     4.69                37.47       37.47      137.47
# 4                    120     5.83                45.65       45.65      145.65
# 5                    240     6.00                32.92       32.92      132.92
# 6                    480     6.41                29.97       29.97      129.97

# %%
new_df[new_df['attempts'] > 2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# f  Michael   20.0         3     yes

# %%
rows = len(new_df.axes[0])
  
# computing number of columns
cols = len(new_df.axes[1])

print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  8
# Number of Columns:  4

# %%
new_df.shape
# Out:
# (8, 4)

# %%
# new_data['High_score'] = new_data['High_score'] ** 2
# new_data['High_score']
new_data['High_score'] **= 2
new_data['High_score']
# Out:
# 0    32015.9449
# 1    25027.2400
# 2    28046.2009
# 3    18898.0009
# 4    21213.9225
# 5    17667.7264
# 6    16892.2009
# Name: High_score, dtype: float64

# %%
type(only_math_score)
# Out:
# pandas.core.series.Series

# %%
sub_df = new_data[['Avg_Math_Test_Score', 'LSD_ppm']]
sub_df
# Out:
#    Avg_Math_Test_Score  LSD_ppm
# 0                78.93     1.17
# 1                58.20     2.97
# 2                67.47     3.26
# 3                37.47     4.69
# 4                45.65     5.83
# 5                32.92     6.00
# 6                29.97     6.41

# %%
X = new_data[['LSD_ppm']]
X
# Out:
#    LSD_ppm
# 0     1.17
# 1     2.97
# 2     3.26
# 3     4.69
# 4     5.83
# 5     6.00
# 6     6.41

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from pandas.core.frame import DataFrame
new_DataFrame = DataFrame([
              {'product_id':23, 'name':'computer', 'wholesale_price': 500,
                'retail_price':1000, 'sales':100
              },
               
              {'product_id':96, 'name':'Python Workout', 'wholesale_price': 35,
                'retail_price':75, 'sales':1000
              },
               
              {'product_id':97, 'name':'Pandas Workout', 'wholesale_price': 35,
               'retail_price':75, 'sales':500
              },

              {'product_id':15, 'name':'banana', 'wholesale_price': 0.5,
               'retail_price':1, 'sales':200
              },
               
              {'product_id':87, 'name':'sandwich', 'wholesale_price': 3,
              'retail_price':5, 'sales':300
              },
])

new_DataFrame
# Out:
#    product_id            name  wholesale_price  retail_price  sales
# 0          23        computer            500.0          1000    100
# 1          96  Python Workout             35.0            75   1000
# 2          97  Pandas Workout             35.0            75    500
# 3          15          banana              0.5             1    200
# 4          87        sandwich              3.0             5    300

# %%
my_list = [
           {
               "Name": "Ayaz lakho", "Roll No.": 75, "Skills": ['Python Basics', "Web Scraping"], "Opt. roll": 35
           },
           {
               "Name": "Turab Bajeer", "Roll No.": 45, "Skills": ['Python Basics', "Web Scraping", "ML DL Java"], "Opt. roll": 25 
           }
]


new_frame = DataFrame(my_list)
extra_column = (new_frame['Roll No.'] - new_frame['Opt. roll'])
new_frame['Difference of Roll and opt roll'] = extra_column

new_frame
# Out:
#            Name  Roll No.                                     Skills  \
# 0    Ayaz lakho        75              [Python Basics, Web Scraping]
# 1  Turab Bajeer        45  [Python Basics, Web Scraping, ML DL Java]
#
#    Opt. roll  Difference of Roll and opt roll
# 0         35                               40
# 1         25                               20
