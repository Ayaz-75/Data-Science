# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

category = []
prices = []

for i in range(1, 50):
    url = "https://www.dtlaprint.com/products/page/"+str(i)+"/"
    response = requests.get(url)
    products_web_page = response.text
    soup = BeautifulSoup(products_web_page, "html.parser")


    product_details = soup.select(selector="div .post_categories")
    for item in product_details:
        texts = item.text.strip().replace("\n", "")
        category.append(texts)



    product_prices = soup.select(selector="div .price")
    for price in product_prices:
        price_text = price.text
        prices.append(price_text)


# print(category)
# print(prices)



products = pd.DataFrame({

                        "product name": category,
                        "product price": prices
})

# %%
products
# Out:
#                                      product name product price
# 0                           Lounge Shorts, Shorts        $27.72
# 1                  Long Sleeve T-Shirts, T-Shirts        $21.12
# 2             Hoodies, Hoodies, Sweaters, Zip Ups        $33.00
# 3     Hoodies, Sweaters, Zip Ups, Raglan Sweaters        $31.68
# 4         Leggings, Sweatpants, Pants, Sweatpants        $29.04
# ...                                           ...           ...
# 1465                         Hats, Six Panel Hats         $4.43
# 1466                         Hats, Six Panel Hats         $4.24
# 1467                  Dress Shirts, Oxford Shirts        $51.51
# 1468                  Dress Shirts, Poplin Shirts        $29.14
# 1469                  Dress Shirts, Poplin Shirts        $29.14
#
# [1470 rows x 2 columns]

# %%
from google.colab import files

products.to_csv("whole_sale_products_dtlaprint.csv",encoding = 'utf-8-sig', index=False)

files.download('whole_sale_products_dtlaprint.csv')
